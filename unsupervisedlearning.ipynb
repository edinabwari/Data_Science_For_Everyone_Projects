# %% [markdown]
# <a href="https://colab.research.google.com/github/edinabwari/Data_Science_For_Everyone_Projects/blob/main/unsupervisedlearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#uploading dataset in colab

# %%
#printing the head of the dataset
df = pd.read_csv('/content/bmi_train.csv')
df.head()
# Out:
#   Gender  Height  Weight  Index
# 0   Male     161      89      4
# 1   Male     179     127      4
# 2   Male     172     139      5
# 3   Male     153     104      5
# 4   Male     165      68      2

# %%
df.describe()
# Out:
#            Height      Weight       Index
# count  400.000000  400.000000  400.000000
# mean   170.362500  106.060000    3.737500
# std     16.574011   32.362242    1.370507
# min    140.000000   50.000000    0.000000
# 25%    156.000000   80.000000    3.000000
# 50%    171.000000  106.500000    4.000000
# 75%    184.000000  136.250000    5.000000
# max    199.000000  160.000000    5.000000

# %%
perc=[.20, .40, .60, .80]
include=['object', 'float', 'int']
df.describe(percentiles=perc, include=include)
# Out:
#        Gender      Height      Weight       Index
# count     400  400.000000  400.000000  400.000000
# unique      2         NaN         NaN         NaN
# top      Male         NaN         NaN         NaN
# freq      200         NaN         NaN         NaN
# mean      NaN  170.362500  106.060000    3.737500
# std       NaN   16.574011   32.362242    1.370507
# min       NaN  140.000000   50.000000    0.000000
# 20%       NaN  153.000000   73.000000    2.000000
# 40%       NaN  166.000000   95.600000    4.000000
# 50%       NaN  171.000000  106.500000    4.000000
# 60%       NaN  178.000000  116.400000    4.000000
# 80%       NaN  186.000000  140.200000    5.000000
# max       NaN  199.000000  160.000000    5.000000

# %%
df.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
df['Weight'].describe
# Out:
# <bound method NDFrame.describe of 0       89
# 1      127
# 2      139
# 3      104
# 4       68
#       ...
# 395    160
# 396    130
# 397    138
# 398    158
# 399    155
# Name: Weight, Length: 400, dtype: int64>

# %%
df.isnull()
# Out:
#      Gender  Height  Weight  Index
# 0     False   False   False  False
# 1     False   False   False  False
# 2     False   False   False  False
# 3     False   False   False  False
# 4     False   False   False  False
# ..      ...     ...     ...    ...
# 395   False   False   False  False
# 396   False   False   False  False
# 397   False   False   False  False
# 398   False   False   False  False
# 399   False   False   False  False
#
# [400 rows x 4 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Length: 400, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  400 non-null    object
#  1   Height  400 non-null    int64
#  2   Weight  400 non-null    int64
#  3   Index   400 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 12.6+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Height', y='Weight', data=df)
plt.title('Height vs Weight')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the Weight column
df['Normalized_Weight'] = scaler.fit_transform(df[['Weight']])

print(df)
# Out:
#     Gender  Height  Weight  Index  Normalized_Weight
# 0     Male     161      89      4           0.354545
# 1     Male     179     127      4           0.700000
# 2     Male     172     139      5           0.809091
# 3     Male     153     104      5           0.490909
# 4     Male     165      68      2           0.163636
# ..     ...     ...     ...    ...                ...
# 395   Male     166     160      5           1.000000
# 396   Male     145     130      5           0.727273
# 397   Male     178     138      5           0.800000
# 398   Male     168     158      5           0.981818
# 399   Male     161     155      5           0.954545
#
# [400 rows x 5 columns]

# %%
df=pd.get_dummies(df,columns=['Gender'])
df.head()
# Out:
#    Height  Weight  Index  Normalized_Weight  Gender_Female  Gender_Male
# 0     161      89      4           0.354545          False         True
# 1     179     127      4           0.700000          False         True
# 2     172     139      5           0.809091          False         True
# 3     153     104      5           0.490909          False         True
# 4     165      68      2           0.163636          False         True

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
LabelEncoder = LabelEncoder()

# Assuming 'Gender' column exists before this step
df['Gender_Female'] = LabelEncoder.fit_transform(df['Gender_Female'])

print(df)
# Out:
#      Height  Weight  Index  Normalized_Weight  Gender_Female  Gender_Male
# 0       161      89      4           0.354545              0         True
# 1       179     127      4           0.700000              0         True
# 2       172     139      5           0.809091              0         True
# 3       153     104      5           0.490909              0         True
# 4       165      68      2           0.163636              0         True
# ..      ...     ...    ...                ...            ...          ...
# 395     166     160      5           1.000000              0         True
# 396     145     130      5           0.727273              0         True
# 397     178     138      5           0.800000              0         True
# 398     168     158      5           0.981818              0         True
# 399     161     155      5           0.954545              0         True
#
# [400 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder = LabelEncoder()
# Assuming 'Gender' column exists before this step
df['Gender_Male'] = LabelEncoder.fit_transform(df['Gender_Male'])

print(df)
# Out:
#      Height  Weight  Index  Normalized_Weight  Gender_Female  Gender_Male
# 0       161      89      4           0.354545              0            1
# 1       179     127      4           0.700000              0            1
# 2       172     139      5           0.809091              0            1
# 3       153     104      5           0.490909              0            1
# 4       165      68      2           0.163636              0            1
# ..      ...     ...    ...                ...            ...          ...
# 395     166     160      5           1.000000              0            1
# 396     145     130      5           0.727273              0            1
# 397     178     138      5           0.800000              0            1
# 398     168     158      5           0.981818              0            1
# 399     161     155      5           0.954545              0            1
#
# [400 rows x 6 columns]

# %%
#saving the preprosed data
df.to_csv('preprocessed_data.csv', index=False)

# %% [markdown]
# # K MEANS CLUSTERING - ELBOW METHOD

# %%
data = pd.read_csv('/content/preprocessed_data.csv')
data.head()
# Out:
#    Height  Weight  Index  Normalized_Weight  Gender_Female  Gender_Male
# 0     161      89      4           0.354545              0            1
# 1     179     127      4           0.700000              0            1
# 2     172     139      5           0.809091              0            1
# 3     153     104      5           0.490909              0            1
# 4     165      68      2           0.163636              0            1

# %%
from sklearn.cluster import KMeans

wcss = [] #empty array
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
